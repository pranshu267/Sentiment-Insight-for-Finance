# %%
import pandas as pd

file_path = '/content/data.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#                                             Sentence Sentiment
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral

# %%
from sklearn.model_selection import train_test_split

train_ratio = 0.7
validation_ratio = 0.15
test_ratio = 0.15

train_data, temp_data = train_test_split(
    data,
    test_size=(1 - train_ratio),
    stratify=data['Sentiment'],
    random_state=42
)

validation_data, test_data = train_test_split(
    temp_data,
    test_size=test_ratio / (test_ratio + validation_ratio),
    stratify=temp_data['Sentiment'],
    random_state=42
)

train_distribution = train_data['Sentiment'].value_counts(normalize=True)
validation_distribution = validation_data['Sentiment'].value_counts(normalize=True)
test_distribution = test_data['Sentiment'].value_counts(normalize=True)

(train_data.shape, validation_data.shape, test_data.shape), train_distribution, validation_distribution, test_distribution
# Out:
# (((4089, 2), (876, 2), (877, 2)),
#  Sentiment
#  neutral     0.535828
#  positive    0.316948
#  negative    0.147224
#  Name: proportion, dtype: float64,
#  Sentiment
#  neutral     0.535388
#  positive    0.317352
#  negative    0.147260
#  Name: proportion, dtype: float64,
#  Sentiment
#  neutral     0.535918
#  positive    0.316990
#  negative    0.147092
#  Name: proportion, dtype: float64)

# %%
train_data_path = '/content/train_data.csv'
validation_data_path = '/content/validation_data.csv'
test_data_path = '/content/test_data.csv'

train_data.to_csv(train_data_path, index=False)
validation_data.to_csv(validation_data_path, index=False)
test_data.to_csv(test_data_path, index=False)

train_data_path, validation_data_path, test_data_path
# Out:
# ('/content/train_data.csv',
#  '/content/validation_data.csv',
#  '/content/test_data.csv')
